# %%
import cv2

# Load the cascade for face detection
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# Start the video capture
cap = cv2.VideoCapture(0)

# Set the initial position of the motor
initial_position = 0

while True:
    # Read the frame
    _, frame = cap.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)

    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        
        

        # Get the center of the face
        face_center_x = x + w/2
        face_center_y = y + h/2

        # Calculate the error from the center of the frame
        error_x = frame.shape[1]/2 - face_center_x
        error_y = frame.shape[0]/2 - face_center_y

        # Move the motor to recenter the camera
        # Replace this with your specific motor control code
        # This is just an example
        
        
        #move_motor(initial_position + error_x, initial_position + error_y)

        # need to move the motor back and forth

    # Show the frame
    cv2.imshow("Face Tracking", frame)

    # Exit if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()

# Close all windows
cv2.destroyAllWindows()

# %%
## Calibration code

import cv2

# Load the cascade for face detection
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# Start the video capture
cap = cv2.VideoCapture(0)

# Set the initial position of the motor
initial_position = 0


print("callibration beginning...")
print("move you face to the distance away from the camera that you desire")
print("when you are happy with the distance, press the 'b' key") #TODO: replace with gesture recognition


desired_face_area = 0 
current_face_area = 0

while True:
    
    # Read the frame
    _, frame = cap.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray,scaleFactor=1.2, minNeighbors=4, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)

    areas=[]
    
    # find the largest face 
    if (len(faces)>1): # if there are more than one face
        for (x, y, w, h) in faces:
            areas.append((x+w)*(y+h))

        print("area list:")
        print(areas)
    
        maxArea = max(areas)
        maxAreaPos = areas.index(maxArea)
        
        print("max area:")
        print(maxArea)
        face = faces[maxAreaPos] #largest face
    
    elif (len(faces)==1):
        face = faces[0]
    
    (x,y,w,h) = face 
        
    # Draw a rectangle around the faces
    cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
    
    # Get the center of the face
    face_center_x = x + w/2
    face_center_y = y + h/2
            
        
    # calculate the area of the desired face rectangle (give an error of +/- 50)
    desired_face_area = (x+w)*(y+h)
    
    # Calculate the error from the center of the frame
    error_x = frame.shape[1]/2 - face_center_x
    error_y = frame.shape[0]/2 - face_center_y
        

    # Move the motor to recenter the camera
    # Replace this with your specific motor control code
    # This is just an example
        
        
    #move_motor(initial_position + error_x, initial_position + error_y)

    # need to move the motor back and forth
    
    # Show the frame
    cv2.imshow("Face Tracking", frame)

    # Exit if the 'b' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('b'):
        break

# Release the video capture
cap.release()

# Close all windows
cv2.destroyAllWindows()

print("final desired face area:")
print(desired_face_area)
# Out:
# callibration beginning...
# move you face to the distance away from the camera that you desire
# when you are happy with the distance, press the 'b' key
# area list:
# [897820, 217756]
# max area:
# 897820
# area list:
# [923919, 211972]
# max area:
# 923919
# area list:
# [927052, 211092]
# max area:
# 927052
# area list:
# [932184, 212366]
# max area:
# 932184
# area list:
# [936096, 211092]
# max area:
# 936096
# area list:
# [940800, 1217710, 215600]
# max area:
# 1217710
# area list:
# [949095, 213246]
# max area:
# 949095
# area list:
# [956610, 213048]
# max area:
# 956610
# area list:
# [949400, 213444, 1368725]
# max area:
# 1368725
# area list:
# [947050, 211484]
# max area:
# 947050
# area list:
# [947418, 1223393, 212366]
# max area:
# 1223393
# area list:
# [957102, 1378173]
# max area:
# 1378173
# area list:
# [962280, 1227849]
# max area:
# 1227849
# area list:
# [126243, 953498]
# max area:
# 953498
# area list:
# [965901, 1382909]
# max area:
# 1382909
# area list:
# [968760, 1404480]
# max area:
# 1404480
# area list:
# [965520, 1235040]
# max area:
# 1235040
# area list:
# [963900, 1240020]
# max area:
# 1240020
# area list:
# [974304, 1236785]
# max area:
# 1236785
# area list:
# [984438, 1247247]
# max area:
# 1247247
# area list:
# [975120, 1392858]
# max area:
# 1392858
# area list:
# [952014, 1397322]
# max area:
# 1397322
# area list:
# [896580, 215800]
# max area:
# 896580
# area list:
# [876555, 213444]
# max area:
# 876555
# area list:
# [875092, 213048]
# max area:
# 875092
# area list:
# [890100, 213246]
# max area:
# 890100
# area list:
# [920972, 212169]
# max area:
# 920972
# area list:
# [931836, 213246]
# max area:
# 931836
# area list:
# [919548, 213246]
# max area:
# 919548
# area list:
# [921725, 214323]
# max area:
# 921725
# area list:
# [926436, 215400]
# max area:
# 926436
# area list:
# [925351, 216477]
# max area:
# 925351
# area list:
# [905458, 215400]
# max area:
# 905458
# area list:
# [908820, 215400]
# max area:
# 908820
# area list:
# [900417, 215200]
# max area:
# 900417
# area list:
# [893648, 1010724, 215400]
# max area:
# 1010724
# area list:
# [892911, 1001742, 215400]
# max area:
# 1001742
# area list:
# [889667, 216477]
# max area:
# 889667
# area list:
# [890478, 216477]
# max area:
# 890478
# area list:
# [893200, 216276]
# max area:
# 893200
# area list:
# [888800, 215200]
# max area:
# 888800
# area list:
# [897842, 215400]
# max area:
# 897842
# area list:
# [891861, 216276]
# max area:
# 891861
# area list:
# [893240, 217554]
# max area:
# 893240
# area list:
# [894055, 216276]
# max area:
# 894055
# area list:
# [896528, 215200]
# max area:
# 896528
# area list:
# [901185, 214522]
# max area:
# 901185
# area list:
# [897070, 212366]
# max area:
# 897070
# area list:
# [909680, 213642]
# max area:
# 909680
# area list:
# [912582, 211092]
# max area:
# 912582
# area list:
# [930143, 211092]
# max area:
# 930143
# area list:
# [926739, 211092]
# max area:
# 926739
# area list:
# [936225, 212169]
# max area:
# 936225
# area list:
# [937320, 212169]
# max area:
# 937320
# area list:
# [935608, 213444]
# max area:
# 935608
# area list:
# [935741, 213246]
# max area:
# 935741
# area list:
# [941355, 213444]
# max area:
# 941355
# area list:
# [935984, 212366]
# max area:
# 935984
# final desired face area:
# 935984

# %% [markdown]
# sarah: make 10,000 the threshold face area that would not encounter change

# %%
## Calibration code

import cv2

# Load the cascade for face detection
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# Start the video capture
cap = cv2.VideoCapture(0)

# Set the initial position of the motor
initial_position = 0

while True:
    
    # Read the frame
    _, frame = cap.read()

    # Convert the frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray,scaleFactor=1.2, minNeighbors=4, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)

    areas=[]
    
    # find the largest face 
    if (len(faces)>1): # if there are more than one face
        for (x, y, w, h) in faces:
            areas.append((x+w)*(y+h))
    
        maxArea = max(areas)
        maxAreaPos = areas.index(maxArea)
        
        face = faces[maxAreaPos] #largest face
    
    elif (len(faces)==1):
        face = faces[0]
    
    (x,y,w,h) = face 
        
    # Draw a rectangle around the faces
    cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
    
    # Get the center of the face
    face_center_x = x + w/2
    face_center_y = y + h/2
            
        
    # calculate the area of the desired face rectangle (give an error of +/- 50)
    current_area = (x+w)*(y+h)
    
    print("desired_face_area")
    print(desired_face_area)
    
    print("current_faca_area")
    print(current_area)
    
    if (current_area - desired_face_area > 75000):
        print("zoom out")
    elif (current_area - desired_face_area<-75000):
        print("zoom in")
    
    # Calculate the error from the center of the frame
    error_x = frame.shape[1]/2 - face_center_x
    error_y = frame.shape[0]/2 - face_center_y
        

    # Move the motor to recenter the camera
    # Replace this with your specific motor control code
    # This is just an example
        
        
    #move_motor(initial_position + error_x, initial_position + error_y)

    # need to move the motor back and forth
    
    # Show the frame
    cv2.imshow("Face Tracking", frame)

    # Exit if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture
cap.release()

# Close all windows
cv2.destroyAllWindows()
# Out:
# desired_face_area
# 935984
# current_faca_area
# 1481952
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 939672
# desired_face_area
# 935984
# current_faca_area
# 941060
# desired_face_area
# 935984
# current_faca_area
# 931252
# desired_face_area
# 935984
# current_faca_area
# 931952
# desired_face_area
# 935984
# current_faca_area
# 933464
# desired_face_area
# 935984
# current_faca_area
# 957008
# desired_face_area
# 935984
# current_faca_area
# 960697
# desired_face_area
# 935984
# current_faca_area
# 960960
# desired_face_area
# 935984
# current_faca_area
# 961480
# desired_face_area
# 935984
# current_faca_area
# 964834
# desired_face_area
# 935984
# current_faca_area
# 966816
# desired_face_area
# 935984
# current_faca_area
# 966456
# desired_face_area
# 935984
# current_faca_area
# 966205
# desired_face_area
# 935984
# current_faca_area
# 963108
# desired_face_area
# 935984
# current_faca_area
# 965697
# desired_face_area
# 935984
# current_faca_area
# 971907
# desired_face_area
# 935984
# current_faca_area
# 969306
# desired_face_area
# 935984
# current_faca_area
# 969054
# desired_face_area
# 935984
# current_faca_area
# 964475
# desired_face_area
# 935984
# current_faca_area
# 961632
# desired_face_area
# 935984
# current_faca_area
# 970920
# desired_face_area
# 935984
# current_faca_area
# 972660
# desired_face_area
# 935984
# current_faca_area
# 973778
# desired_face_area
# 935984
# current_faca_area
# 970050
# desired_face_area
# 935984
# current_faca_area
# 970673
# desired_face_area
# 935984
# current_faca_area
# 966952
# desired_face_area
# 935984
# current_faca_area
# 968066
# desired_face_area
# 935984
# current_faca_area
# 966952
# desired_face_area
# 935984
# current_faca_area
# 964971
# desired_face_area
# 935984
# current_faca_area
# 958176
# desired_face_area
# 935984
# current_faca_area
# 959285
# desired_face_area
# 935984
# current_faca_area
# 961015
# desired_face_area
# 935984
# current_faca_area
# 962992
# desired_face_area
# 935984
# current_faca_area
# 966084
# desired_face_area
# 935984
# current_faca_area
# 958544
# desired_face_area
# 935984
# current_faca_area
# 962992
# desired_face_area
# 935984
# current_faca_area
# 963858
# desired_face_area
# 935984
# current_faca_area
# 968688
# desired_face_area
# 935984
# current_faca_area
# 968439
# desired_face_area
# 935984
# current_faca_area
# 961632
# desired_face_area
# 935984
# current_faca_area
# 973152
# desired_face_area
# 935984
# current_faca_area
# 968310
# desired_face_area
# 935984
# current_faca_area
# 962370
# desired_face_area
# 935984
# current_faca_area
# 964348
# desired_face_area
# 935984
# current_faca_area
# 964348
# desired_face_area
# 935984
# current_faca_area
# 966084
# desired_face_area
# 935984
# current_faca_area
# 968688
# desired_face_area
# 935984
# current_faca_area
# 952020
# desired_face_area
# 935984
# current_faca_area
# 964348
# desired_face_area
# 935984
# current_faca_area
# 976500
# desired_face_area
# 935984
# current_faca_area
# 1009560
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1057056
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1057410
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1090232
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1109934
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1168120
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1170190
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197495
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1186800
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1189328
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1199232
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1174624
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1166990
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1180304
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1167290
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1182282
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1177092
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1182282
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1171216
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1182076
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1177402
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1177290
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1179686
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1173170
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1185998
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1182785
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1181526
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1166450
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1178088
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1173744
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1174770
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1173861
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1173861
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1180380
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1171692
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1182200
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1175915
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1166220
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1169289
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1172718
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1162128
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1161898
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1160877
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1166102
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1162556
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1159502
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1159256
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1155440
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1148400
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1103778
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1078324
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1062600
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1029656
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1019466
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 995214
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 991609
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 968935
# desired_face_area
# 935984
# current_faca_area
# 960268
# desired_face_area
# 935984
# current_faca_area
# 958293
# desired_face_area
# 935984
# current_faca_area
# 954349
# desired_face_area
# 935984
# current_faca_area
# 959406
# desired_face_area
# 935984
# current_faca_area
# 956571
# desired_face_area
# 935984
# current_faca_area
# 960519
# desired_face_area
# 935984
# current_faca_area
# 955096
# desired_face_area
# 935984
# current_faca_area
# 947842
# desired_face_area
# 935984
# current_faca_area
# 950913
# desired_face_area
# 935984
# current_faca_area
# 951772
# desired_face_area
# 935984
# current_faca_area
# 942456
# desired_face_area
# 935984
# current_faca_area
# 948090
# desired_face_area
# 935984
# current_faca_area
# 946374
# desired_face_area
# 935984
# current_faca_area
# 947232
# desired_face_area
# 935984
# current_faca_area
# 948336
# desired_face_area
# 935984
# current_faca_area
# 947477
# desired_face_area
# 935984
# current_faca_area
# 943557
# desired_face_area
# 935984
# current_faca_area
# 939645
# desired_face_area
# 935984
# current_faca_area
# 944658
# desired_face_area
# 935984
# current_faca_area
# 937935
# desired_face_area
# 935984
# current_faca_area
# 935249
# desired_face_area
# 935984
# current_faca_area
# 935249
# desired_face_area
# 935984
# current_faca_area
# 932696
# desired_face_area
# 935984
# current_faca_area
# 932088
# desired_face_area
# 935984
# current_faca_area
# 938415
# desired_face_area
# 935984
# current_faca_area
# 952833
# desired_face_area
# 935984
# current_faca_area
# 954800
# desired_face_area
# 935984
# current_faca_area
# 969732
# desired_face_area
# 935984
# current_faca_area
# 963326
# desired_face_area
# 935984
# current_faca_area
# 969804
# desired_face_area
# 935984
# current_faca_area
# 949195
# desired_face_area
# 935984
# current_faca_area
# 953856
# desired_face_area
# 935984
# current_faca_area
# 951966
# desired_face_area
# 935984
# current_faca_area
# 947856
# desired_face_area
# 935984
# current_faca_area
# 957456
# desired_face_area
# 935984
# current_faca_area
# 965360
# desired_face_area
# 935984
# current_faca_area
# 985188
# desired_face_area
# 935984
# current_faca_area
# 981200
# desired_face_area
# 935984
# current_faca_area
# 963353
# desired_face_area
# 935984
# current_faca_area
# 941562
# desired_face_area
# 935984
# current_faca_area
# 938081
# desired_face_area
# 935984
# current_faca_area
# 915607
# desired_face_area
# 935984
# current_faca_area
# 904442
# desired_face_area
# 935984
# current_faca_area
# 1021878
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 882994
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 877212
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 1015119
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1015751
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1009640
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 878202
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 880925
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 889340
# desired_face_area
# 935984
# current_faca_area
# 1012299
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1019520
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1022430
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1020384
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1020384
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1018340
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 903305
# desired_face_area
# 935984
# current_faca_area
# 1022112
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1026210
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1019203
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1022746
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1020384
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1019520
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 895700
# desired_face_area
# 935984
# current_faca_area
# 895484
# desired_face_area
# 935984
# current_faca_area
# 897606
# desired_face_area
# 935984
# current_faca_area
# 892952
# desired_face_area
# 935984
# current_faca_area
# 895700
# desired_face_area
# 935984
# current_faca_area
# 898667
# desired_face_area
# 935984
# current_faca_area
# 897390
# desired_face_area
# 935984
# current_faca_area
# 1008780
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 897820
# desired_face_area
# 935984
# current_faca_area
# 896545
# desired_face_area
# 935984
# current_faca_area
# 894855
# desired_face_area
# 935984
# current_faca_area
# 894010
# desired_face_area
# 935984
# current_faca_area
# 892952
# desired_face_area
# 935984
# current_faca_area
# 1007060
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 900361
# desired_face_area
# 935984
# current_faca_area
# 896545
# desired_face_area
# 935984
# current_faca_area
# 900548
# desired_face_area
# 935984
# current_faca_area
# 903749
# desired_face_area
# 935984
# current_faca_area
# 898414
# desired_face_area
# 935984
# current_faca_area
# 1015338
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 905520
# desired_face_area
# 935984
# current_faca_area
# 1022868
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 905471
# desired_face_area
# 935984
# current_faca_area
# 902781
# desired_face_area
# 935984
# current_faca_area
# 898984
# desired_face_area
# 935984
# current_faca_area
# 894348
# desired_face_area
# 935984
# current_faca_area
# 901719
# desired_face_area
# 935984
# current_faca_area
# 894586
# desired_face_area
# 935984
# current_faca_area
# 890928
# desired_face_area
# 935984
# current_faca_area
# 884184
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 881640
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 886836
# desired_face_area
# 935984
# current_faca_area
# 875750
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 890340
# desired_face_area
# 935984
# current_faca_area
# 882396
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 891648
# desired_face_area
# 935984
# current_faca_area
# 880134
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 884730
# zoom in
# desired_face_area
# 935984
# current_faca_area
# 886565
# desired_face_area
# 935984
# current_faca_area
# 898157
# desired_face_area
# 935984
# current_faca_area
# 944832
# desired_face_area
# 935984
# current_faca_area
# 986244
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 991744
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1024604
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1052359
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1066664
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1488954
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1483316
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1092032
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1110484
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1140800
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1168080
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1177043
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1222577
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1223424
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1226123
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1256541
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1262644
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1257854
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1262044
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1282464
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1257100
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1261304
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1280202
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1282490
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1294611
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1285732
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1285732
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1295258
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306800
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1300192
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1316712
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1311086
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1314395
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1314395
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1305147
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1305472
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1291950
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1298557
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1313049
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1308690
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1304386
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1303388
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1312686
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1316000
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1319318
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1311055
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1310058
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1314000
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1303134
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1305122
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1316362
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1312728
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1298528
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1301823
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1311732
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1300192
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1302174
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306788
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1307781
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1311732
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1315364
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1307110
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1310736
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1308064
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1309000
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1295182
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1302301
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1310818
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1315020
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306079
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1307376
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1304637
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1303344
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1295445
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1295445
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1295445
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1298023
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1307086
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1308673
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1304352
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306940
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306940
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1293995
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1303344
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306655
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1295728
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1298304
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1306492
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1302168
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1302168
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1296565
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1302444
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1308060
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1308335
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1314510
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1316548
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1461328
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1300962
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1289232
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1300743
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1317370
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1298432
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1285992
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1250248
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1243125
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1232640
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1196208
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1158038
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1130016
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1095232
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1087988
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1088370
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1081634
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1065432
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1049916
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1062968
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1062620
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1071000
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1075896
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1069404
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1061502
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1062810
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1047696
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1047454
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1050720
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1021380
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 993510
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 988121
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1001943
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 991587
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1042131
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1016502
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1043739
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1036260
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1065402
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1055420
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1078590
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1076824
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1108339
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1127464
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1160523
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1124082
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1128361
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1159374
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1169316
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1149120
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1144090
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1158000
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1136902
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1168860
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1189744
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1196076
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1185358
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1201408
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1196244
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1179239
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1191088
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1156138
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1147932
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1183656
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1155420
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1154040
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1138780
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1139968
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1169656
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1155604
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1161414
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1173170
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1173788
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1181143
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1190800
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197258
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1210852
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1210650
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1209600
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1299520
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1210950
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1205685
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1218721
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1213866
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1201965
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1189381
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197060
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197000
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1188320
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1187371
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1189440
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1195995
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1194620
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1198638
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1194482
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1215088
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1221300
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1224106
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1221990
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1218721
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1220150
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197344
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1195540
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1188837
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1180785
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1180728
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1187616
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1187076
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1215520
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1186308
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197228
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1204875
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197378
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1198349
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1200591
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1213675
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1207272
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1205243
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1218032
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1215768
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1212546
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1206196
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1211472
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1219050
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1210450
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1209216
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1204979
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1199308
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1196260
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197330
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1211525
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1208198
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1217916
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1222080
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1220064
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1228792
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1222011
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1226508
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1218928
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1221074
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1215709
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1220870
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1204704
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1207710
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1204235
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1196808
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1202448
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1208775
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1195812
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1205890
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1213179
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1209840
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1204379
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1207640
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1201122
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1209768
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1202184
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1216152
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1220648
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1230579
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1219869
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1222080
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1216656
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1203694
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1205772
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1213179
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1212372
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1212490
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1222147
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1217447
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1233950
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1201052
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1234242
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1205370
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1219729
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1211896
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1208911
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1212180
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1203636
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1201382
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1225150
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1223685
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1234519
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1225360
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1225548
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1226966
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1223685
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1210757
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1192968
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1197800
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1207970
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1377018
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1182588
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1207340
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1399464
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1401510
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1402184
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1402184
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1397749
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1207844
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1224080
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1390935
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1215165
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1227512
# zoom out
# desired_face_area
# 935984
# current_faca_area
# 1219425
# zoom out
